# %% [markdown]
# ___
# # `ООП`
# ## СОДЕРЖАНИЕ
# - [Импорт класса из файла](#c)
# - [Библиотека OS](#os)
# - [Чтение и запись файлов](#f)
# - [TRY-EXCEPT](#try)
#
#
#
# ___
# ## Принципы ООП
# - ### `Наследование`
# Новый класс создается на основе родительского: все атрибуты и методы от родительского переходят наследуемому
# - ### `Абстракция`
# Некоторые свойства конкретного класса выделяются как главные и второстепенные
# - ### `Инкапсуляция`
# Объединение свойств внутри класса и ограничение доступа к данным внутри класса
# - ### `Полиморфизм`
# Свойство системы, позволяющее иметь множество реализаций одного интерфейса
# ___
# ## Применяется
# - Для создании объекта с `изменяющимися атрибутами`
# - Для создания `последовательностей применения функций` к объекту

# %% [markdown]
# ___
# ### <a>__init\_\_</a>(self, _a_) : Инициирует атрибут _a_ `при создании класса`
# - `self `: Объект класса

# %%
class TestClass():
    def __init__(self, attribute):
        self.attribute = attribute

test = TestClass(100)
test.attribute
# Out:
# 100

# %% [markdown]
# ___
# ## <a id= 'c'>Импорт класса из файла</a>
#
# Если файлов с классами много, их можно складывать в папки, предварительно положив туда пустой файл __init__.py — это требование Python

# %%
from folder_name.class_file import TestClass

test = TestClass(100)
test.attribute
# Out:
# 100

# %% [markdown]
# ## <a id= 'os'>Библиотека os</a>

# %% [markdown]
# ___
# ### Текущий путь

# %%
import os
start_path = os.getcwd()
start_path
# Out:
# 'c:\\Users\\nazar\\YandexDisk\\MIPT.Data Science'

# %% [markdown]
# ____
# ### Перемещение по папкам

# %%
os.chdir("..")
os.getcwd()
# Out:
# 'c:\\Users\\nazar\\YandexDisk'

# %%
os.chdir(start_path)
os.getcwd()
# Out:
# 'c:\\Users\\nazar\\YandexDisk\\MIPT.Data Science'

# %% [markdown]
# ____
# ### Список всех вложенных папок

# %%
os.listdir()
# Out:
# ['desktop.ini',
#  'English',
#  'Python',
#  'ВКР',
#  'Математика и алгоритмы ML',
#  'Методология научных исследований',
#  'Продвинутые методы машинного обучения']

# %% [markdown]
# ____
# ### Создание нового пути

# %%
print(os.path.join(start_path, 'another'))
# Out:
# c:\Users\nazar\YandexDisk\MIPT.Data Science\another

# %% [markdown]
# ___
# ### Функция для отображения всех вложенных файлов и папок

# %%
import os

def walk_desc(path=None):
    start_path = path if path is not None else os.getcwd()

    for root, dirs, files in os.walk(start_path):
        print("Текущая директория", root)
        print("---")

        if dirs:
            print("Список папок", dirs)
        else:
            print("Папок нет")
        print("---")

        if files:
            print("Список файлов", files)
        else:
            print("Файлов нет")
        print("---")

        if files and dirs:
            print("Все пути:")
        for f in files:
            print("Файл ", os.path.join(root, f))
        for d in dirs:
            print("Папка ", os.path.join(root, d))
        print("===")

walk_desc()
# Out:
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science
# ---
# Список папок ['English', 'Python', 'ВКР', 'Математика и алгоритмы ML', 'Методология научных исследований', 'Продвинутые методы машинного обучения']
# ---
# Список файлов ['desktop.ini']
# ---
# Все пути:
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\desktop.ini
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\English
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\ВКР
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Математика и алгоритмы ML
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Методология научных исследований
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\English
# ---
# Список папок ['1', '10', '11', '2', '3', '4', '5', '6', '7', '8', '9', 'Cover letter', 'Errors', 'Product description']
# ---
# Список файлов ['Vacabulary Business English.xlsx']
# ---
# Все пути:
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\Vacabulary Business English.xlsx
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\1
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\10
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\11
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\2
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\3
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\4
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\5
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\6
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\7
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\8
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\9
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\Cover letter
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\Errors
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\Product description
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\English\1
# ---
# Папок нет
# ---
# Список файлов ['About myself.docx']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\1\About myself.docx
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\English\10
# ---
# Папок нет
# ---
# Список файлов ['3.5. Webinar Case Study “Business risks assessment”.docx.pdf']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\10\3.5. Webinar Case Study “Business risks assessment”.docx.pdf
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\English\11
# ---
# Папок нет
# ---
# Список файлов ['4.1. Webinar Structuring a presentation. Signposting language..docx-2.pdf']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\11\4.1. Webinar Structuring a presentation. Signposting language..docx-2.pdf
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\English\2
# ---
# Папок нет
# ---
# Список файлов ['Unit 1.2. Careers, personal skills and qualities Students Version.docx.pdf']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\2\Unit 1.2. Careers, personal skills and qualities Students Version.docx.pdf
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\English\3
# ---
# Папок нет
# ---
# Список файлов ['1.4. Webinar Job interviews.docx.pdf', 'asset-v1_SkillFactory+MFTIDS+SEP2023+type@asset+block@1.3._Sample_CV (1).pdf']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\3\1.4. Webinar Job interviews.docx.pdf
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\3\asset-v1_SkillFactory+MFTIDS+SEP2023+type@asset+block@1.3._Sample_CV (1).pdf
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\English\4
# ---
# Папок нет
# ---
# Список файлов ['Candidate #1.mp3', 'Candidate #2.mp3', 'Candidate #3.mp3', 'Candidate #4.mp3', 'Unit 1.6. Synch.docx.pdf', 'Unit 1_Case.docx.pdf']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\4\Candidate #1.mp3
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\4\Candidate #2.mp3
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\4\Candidate #3.mp3
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\4\Candidate #4.mp3
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\4\Unit 1.6. Synch.docx.pdf
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\4\Unit 1_Case.docx.pdf
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\English\5
# ---
# Папок нет
# ---
# Список файлов ['for student Unit 1.2_COMPUTERS_synch.pdf', 'PC_listening.mp3']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\5\for student Unit 1.2_COMPUTERS_synch.pdf
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\5\PC_listening.mp3
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\English\6
# ---
# Папок нет
# ---
# Список файлов ['2.3. Art Intell Synch.docx.pdf']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\6\2.3. Art Intell Synch.docx.pdf
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\English\7
# ---
# Список папок ['img']
# ---
# Список файлов ['About Big Data.rtf', 'big data.pptx', 'Round_table_discussion_DS.pdf']
# ---
# Все пути:
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\7\About Big Data.rtf
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\7\big data.pptx
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\7\Round_table_discussion_DS.pdf
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\7\img
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\English\7\img
# ---
# Папок нет
# ---
# Список файлов ['BD.jpg', 'main.jpg', 'Used for.jpg', 'What is Big Data.jpg', 'Works.jpg']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\7\img\BD.jpg
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\7\img\main.jpg
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\7\img\Used for.jpg
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\7\img\What is Big Data.jpg
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\7\img\Works.jpg
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\English\8
# ---
# Папок нет
# ---
# Список файлов ['3.1. Webinar New product development_2023.docx.pdf']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\8\3.1. Webinar New product development_2023.docx.pdf
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\English\9
# ---
# Папок нет
# ---
# Список файлов ['3.3. Webinar Marketing instruments.docx.pdf']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\9\3.3. Webinar Marketing instruments.docx.pdf
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\English\Cover letter
# ---
# Папок нет
# ---
# Список файлов ['Cover letter.docx']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\Cover letter\Cover letter.docx
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\English\Errors
# ---
# Папок нет
# ---
# Список файлов ['testerror_p1.png', 'testerror_p2.png']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\Errors\testerror_p1.png
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\Errors\testerror_p2.png
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\English\Product description
# ---
# Папок нет
# ---
# Список файлов ['Writing task 2. Digital product description.rtf']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\English\Product description\Writing task 2. Digital product description.rtf
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python
# ---
# Список папок ['.idea', '.ipynb_checkpoints', '1 - Функции', '2 - DS инструменты', '3 - Numpy', '4 - Pandas', '5 - Визуализация', '6 - Очистка данных', '7 - Работа с файлами', '8 - API', '9 - ООП.ipynb', 'HomeWorks', 'Seminar', 'Статистика']
# ---
# Список файлов ['desktop.ini']
# ---
# Все пути:
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\desktop.ini
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\.idea
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\.ipynb_checkpoints
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\1 - Функции
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\3 - Numpy
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\5 - Визуализация
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\6 - Очистка данных
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\7 - Работа с файлами
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\8 - API
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\9 - ООП.ipynb
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\HomeWorks
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\Seminar
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\Статистика
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\.idea
# ---
# Список папок ['inspectionProfiles']
# ---
# Список файлов ['.gitignore', '.name', 'misc.xml', 'modules.xml', 'Python MIPT.iml', 'vcs.xml', 'workspace-nMs.xml', 'workspace.xml']
# ---
# Все пути:
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\.idea\.gitignore
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\.idea\.name
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\.idea\misc.xml
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\.idea\modules.xml
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\.idea\Python MIPT.iml
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\.idea\vcs.xml
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\.idea\workspace-nMs.xml
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\.idea\workspace.xml
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\.idea\inspectionProfiles
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\.idea\inspectionProfiles
# ---
# Папок нет
# ---
# Список файлов ['profiles_settings.xml']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\.idea\inspectionProfiles\profiles_settings.xml
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\.ipynb_checkpoints
# ---
# Папок нет
# ---
# Список файлов ['Func.(filter)-checkpoint.ipynb', 'Functions (Cours)-checkpoint.ipynb', 'HomeWork -1-checkpoint.ipynb', 'HW-1(Project)-checkpoint.ipynb', 'HW-1-checkpoint.ipynb', 'LESSON 1-checkpoint.ipynb', 'Lesson3-checkpoint.ipynb', 'Untitled-checkpoint.ipynb', 'Untitled1-checkpoint.ipynb', 'Функции Python-checkpoint.ipynb']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\.ipynb_checkpoints\Func.(filter)-checkpoint.ipynb
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\.ipynb_checkpoints\Functions (Cours)-checkpoint.ipynb
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\.ipynb_checkpoints\HomeWork -1-checkpoint.ipynb
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\.ipynb_checkpoints\HW-1(Project)-checkpoint.ipynb
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\.ipynb_checkpoints\HW-1-checkpoint.ipynb
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\.ipynb_checkpoints\LESSON 1-checkpoint.ipynb
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\.ipynb_checkpoints\Lesson3-checkpoint.ipynb
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\.ipynb_checkpoints\Untitled-checkpoint.ipynb
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\.ipynb_checkpoints\Untitled1-checkpoint.ipynb
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\.ipynb_checkpoints\Функции Python-checkpoint.ipynb
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\1 - Функции
# ---
# Список папок ['.ipynb_checkpoints']
# ---
# Список файлов ['Func.(filter).ipynb', 'Functions (Cours).ipynb']
# ---
# Все пути:
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\1 - Функции\Func.(filter).ipynb
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\1 - Функции\Functions (Cours).ipynb
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\1 - Функции\.ipynb_checkpoints
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\1 - Функции\.ipynb_checkpoints
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты
# ---
# Список папок ['.git', 'Example Project', '__pycache__']
# ---
# Список файлов ['README.md', 'requirements.txt']
# ---
# Все пути:
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\README.md
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\requirements.txt
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\Example Project
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\__pycache__
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git
# ---
# Список папок ['hooks', 'info', 'logs', 'objects', 'refs']
# ---
# Список файлов ['COMMIT_EDITMSG', 'config', 'description', 'FETCH_HEAD', 'HEAD', 'index', 'ORIG_HEAD']
# ---
# Все пути:
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\COMMIT_EDITMSG
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\config
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\description
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\FETCH_HEAD
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\HEAD
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\index
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\ORIG_HEAD
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\hooks
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\info
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\logs
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\refs
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\hooks
# ---
# Папок нет
# ---
# Список файлов ['applypatch-msg.sample', 'commit-msg.sample', 'fsmonitor-watchman.sample', 'post-update.sample', 'pre-applypatch.sample', 'pre-commit.sample', 'pre-merge-commit.sample', 'pre-push.sample', 'pre-rebase.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'push-to-checkout.sample', 'update.sample']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\hooks\applypatch-msg.sample
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\hooks\commit-msg.sample
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\hooks\fsmonitor-watchman.sample
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\hooks\post-update.sample
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\hooks\pre-applypatch.sample
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\hooks\pre-commit.sample
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\hooks\pre-merge-commit.sample
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\hooks\pre-push.sample
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\hooks\pre-rebase.sample
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\hooks\pre-receive.sample
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\hooks\prepare-commit-msg.sample
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\hooks\push-to-checkout.sample
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\hooks\update.sample
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\info
# ---
# Папок нет
# ---
# Список файлов ['exclude']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\info\exclude
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\logs
# ---
# Список папок ['refs']
# ---
# Список файлов ['HEAD']
# ---
# Все пути:
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\logs\HEAD
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\logs\refs
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\logs\refs
# ---
# Список папок ['heads', 'remotes']
# ---
# Файлов нет
# ---
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\logs\refs\heads
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\logs\refs\remotes
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\logs\refs\heads
# ---
# Папок нет
# ---
# Список файлов ['main']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\logs\refs\heads\main
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\logs\refs\remotes
# ---
# Список папок ['origin']
# ---
# Файлов нет
# ---
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\logs\refs\remotes\origin
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\logs\refs\remotes\origin
# ---
# Папок нет
# ---
# Список файлов ['main']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\logs\refs\remotes\origin\main
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects
# ---
# Список папок ['01', '05', '0a', '17', '1b', '38', '42', '58', '59', '5d', '65', '66', '6e', '71', '72', '86', '87', '8a', '8c', '95', '98', 'aa', 'bb', 'c0', 'c3', 'c4', 'cc', 'cd', 'd7', 'db', 'de', 'e4', 'e6', 'e7', 'eb', 'ed', 'info', 'pack']
# ---
# Файлов нет
# ---
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\01
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\05
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\0a
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\17
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\1b
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\38
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\42
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\58
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\59
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\5d
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\65
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\66
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\6e
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\71
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\72
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\86
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\87
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\8a
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\8c
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\95
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\98
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\aa
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\bb
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\c0
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\c3
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\c4
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\cc
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\cd
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\d7
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\db
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\de
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\e4
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\e6
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\e7
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\eb
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\ed
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\info
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\pack
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\01
# ---
# Папок нет
# ---
# Список файлов ['8e28534a320495a7a0959d3da75a40ac54c2b1']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\01\8e28534a320495a7a0959d3da75a40ac54c2b1
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\05
# ---
# Папок нет
# ---
# Список файлов ['b9b15ddbfc634a2b0398d6708b63ef7de61681']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\05\b9b15ddbfc634a2b0398d6708b63ef7de61681
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\0a
# ---
# Папок нет
# ---
# Список файлов ['c830a8074d4a046fa4f2d233f6ecb98f102a57']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\0a\c830a8074d4a046fa4f2d233f6ecb98f102a57
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\17
# ---
# Папок нет
# ---
# Список файлов ['45a1bcb7f7301a95500a615ee5453b227039ac']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\17\45a1bcb7f7301a95500a615ee5453b227039ac
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\1b
# ---
# Папок нет
# ---
# Список файлов ['9cb098cdf0e1b01f87216e5e86d81f333484bb']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\1b\9cb098cdf0e1b01f87216e5e86d81f333484bb
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\38
# ---
# Папок нет
# ---
# Список файлов ['48e825046f46be2269cd5aae4b9ffc91a31426']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\38\48e825046f46be2269cd5aae4b9ffc91a31426
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\42
# ---
# Папок нет
# ---
# Список файлов ['9edf2e5d14eb441623d84a73d363563f83180a']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\42\9edf2e5d14eb441623d84a73d363563f83180a
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\58
# ---
# Папок нет
# ---
# Список файлов ['b67c97400b39534fd23e3294fd835168932672']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\58\b67c97400b39534fd23e3294fd835168932672
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\59
# ---
# Папок нет
# ---
# Список файлов ['a602806572a768d8dfb920a04c91c33e1cb4f6']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\59\a602806572a768d8dfb920a04c91c33e1cb4f6
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\5d
# ---
# Папок нет
# ---
# Список файлов ['fb9447689924d8b0f4c9f38689a19eb28fce8b']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\5d\fb9447689924d8b0f4c9f38689a19eb28fce8b
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\65
# ---
# Папок нет
# ---
# Список файлов ['f4e0df414b9cba4672de6c6b869f6a23166210']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\65\f4e0df414b9cba4672de6c6b869f6a23166210
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\66
# ---
# Папок нет
# ---
# Список файлов ['33f939679668b7e479eaf85fff96cf74ad6072']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\66\33f939679668b7e479eaf85fff96cf74ad6072
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\6e
# ---
# Папок нет
# ---
# Список файлов ['35a3da43747c707ef22cbc2ca62c04877bdc9c']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\6e\35a3da43747c707ef22cbc2ca62c04877bdc9c
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\71
# ---
# Папок нет
# ---
# Список файлов ['cf0c98aaa7b4cbcaac6d452b8a1960893addc5']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\71\cf0c98aaa7b4cbcaac6d452b8a1960893addc5
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\72
# ---
# Папок нет
# ---
# Список файлов ['55aa73b956ff7f8b6428f402fdd93fd701971e']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\72\55aa73b956ff7f8b6428f402fdd93fd701971e
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\86
# ---
# Папок нет
# ---
# Список файлов ['0de0317c1f982c19fc433b59405f3c08ed7b5c']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\86\0de0317c1f982c19fc433b59405f3c08ed7b5c
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\87
# ---
# Папок нет
# ---
# Список файлов ['9bf67d295b903e38cf7fa11860917737061b0f']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\87\9bf67d295b903e38cf7fa11860917737061b0f
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\8a
# ---
# Папок нет
# ---
# Список файлов ['f3348465715121ae33ee97eddaf7918d73bee6']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\8a\f3348465715121ae33ee97eddaf7918d73bee6
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\8c
# ---
# Папок нет
# ---
# Список файлов ['d837323965a17bac02c70dbedfa2f1de9c37a9']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\8c\d837323965a17bac02c70dbedfa2f1de9c37a9
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\95
# ---
# Папок нет
# ---
# Список файлов ['6745db88ae070df84d56761c6e3956570007ee']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\95\6745db88ae070df84d56761c6e3956570007ee
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\98
# ---
# Папок нет
# ---
# Список файлов ['b37356cfe087965146def9444dccc8d759e27b']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\98\b37356cfe087965146def9444dccc8d759e27b
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\aa
# ---
# Папок нет
# ---
# Список файлов ['f240adec02c76f91e22207f6b941fee32823e4']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\aa\f240adec02c76f91e22207f6b941fee32823e4
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\bb
# ---
# Папок нет
# ---
# Список файлов ['4f02b2145dbb5f9ea487a0790243709255ef75']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\bb\4f02b2145dbb5f9ea487a0790243709255ef75
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\c0
# ---
# Папок нет
# ---
# Список файлов ['a969ac828fa247d8ce0c501ca3c3f39aceaae8']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\c0\a969ac828fa247d8ce0c501ca3c3f39aceaae8
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\c3
# ---
# Папок нет
# ---
# Список файлов ['97a6720c9dad6861de2eb9adca51a338f37078']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\c3\97a6720c9dad6861de2eb9adca51a338f37078
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\c4
# ---
# Папок нет
# ---
# Список файлов ['f03726c18221f920894b026ab4f0bca1eb5a72']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\c4\f03726c18221f920894b026ab4f0bca1eb5a72
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\cc
# ---
# Папок нет
# ---
# Список файлов ['2e505093d01c182bc05f95e3a459b5b61812f3']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\cc\2e505093d01c182bc05f95e3a459b5b61812f3
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\cd
# ---
# Папок нет
# ---
# Список файлов ['cf33e2890308d5504c09f26d94659709467f4e']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\cd\cf33e2890308d5504c09f26d94659709467f4e
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\d7
# ---
# Папок нет
# ---
# Список файлов ['77f5c01a7a658c6ab5ad40a99a5e9f383f1c03']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\d7\77f5c01a7a658c6ab5ad40a99a5e9f383f1c03
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\db
# ---
# Папок нет
# ---
# Список файлов ['daa61d1dc47849ec66f3fccf946ac5488dda81']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\db\daa61d1dc47849ec66f3fccf946ac5488dda81
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\de
# ---
# Папок нет
# ---
# Список файлов ['c35f14fab0a17e3ad36346b4d7ea747fa72388']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\de\c35f14fab0a17e3ad36346b4d7ea747fa72388
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\e4
# ---
# Папок нет
# ---
# Список файлов ['338e9085a395903ad1e42355380115b3bad901']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\e4\338e9085a395903ad1e42355380115b3bad901
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\e6
# ---
# Папок нет
# ---
# Список файлов ['9de29bb2d1d6434b8b29ae775ad8c2e48c5391']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\e6\9de29bb2d1d6434b8b29ae775ad8c2e48c5391
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\e7
# ---
# Папок нет
# ---
# Список файлов ['7628a3f4596db8ff76f6cba2ab942c10d032d5']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\e7\7628a3f4596db8ff76f6cba2ab942c10d032d5
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\eb
# ---
# Папок нет
# ---
# Список файлов ['61664f2f53da387bb19caa72b54917c6d28f25']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\eb\61664f2f53da387bb19caa72b54917c6d28f25
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\ed
# ---
# Папок нет
# ---
# Список файлов ['a9f2eb7afedf0c163fd80f1080da51aa55b324']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\ed\a9f2eb7afedf0c163fd80f1080da51aa55b324
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\info
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\objects\pack
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\refs
# ---
# Список папок ['heads', 'remotes', 'tags']
# ---
# Файлов нет
# ---
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\refs\heads
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\refs\remotes
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\refs\tags
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\refs\heads
# ---
# Папок нет
# ---
# Список файлов ['main']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\refs\heads\main
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\refs\remotes
# ---
# Список папок ['origin']
# ---
# Файлов нет
# ---
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\refs\remotes\origin
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\refs\remotes\origin
# ---
# Папок нет
# ---
# Список файлов ['main']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\refs\remotes\origin\main
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\.git\refs\tags
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\Example Project
# ---
# Папок нет
# ---
# Список файлов ['example.py', 'example2.py', 'example_jup.ipynb', 'Readme.md']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\Example Project\example.py
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\Example Project\example2.py
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\Example Project\example_jup.ipynb
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\Example Project\Readme.md
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\__pycache__
# ---
# Папок нет
# ---
# Список файлов ['example2.cpython-311.pyc']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\2 - DS инструменты\__pycache__\example2.cpython-311.pyc
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\3 - Numpy
# ---
# Список папок ['data']
# ---
# Список файлов ['bracket line.py', 'Collections.ipynb', 'deque_defdict.py', 'Numpy Arrays.ipynb', 'Numpy IMAGES.ipynb', 'Numpy_Data_types.ipynb']
# ---
# Все пути:
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\3 - Numpy\bracket line.py
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\3 - Numpy\Collections.ipynb
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\3 - Numpy\deque_defdict.py
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\3 - Numpy\Numpy Arrays.ipynb
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\3 - Numpy\Numpy IMAGES.ipynb
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\3 - Numpy\Numpy_Data_types.ipynb
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\3 - Numpy\data
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\3 - Numpy\data
# ---
# Папок нет
# ---
# Список файлов ['numpylogo.png', 'numpy_image.jpg', 'pixel.png', 'pythonlogo.png']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\3 - Numpy\data\numpylogo.png
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\3 - Numpy\data\numpy_image.jpg
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\3 - Numpy\data\pixel.png
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\3 - Numpy\data\pythonlogo.png
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas
# ---
# Список папок ['Конспект', 'Литература', 'Примеры анализа', 'Функции']
# ---
# Файлов нет
# ---
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Литература
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Функции
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект
# ---
# Список папок ['data', 'img']
# ---
# Список файлов ['Pandas DataFrame.ipynb', 'Pandas Series.ipynb']
# ---
# Все пути:
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\Pandas DataFrame.ipynb
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\Pandas Series.ipynb
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\data
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\img
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\data
# ---
# Список папок ['movies_data']
# ---
# Список файлов ['citibike-tripdata.csv', 'countries.csv', 'countries.zip', 'data_ufo.csv', 'df_to_excel (2).xlsx', 'df_to_excel.xlsx', 'df_to_json.js', 'groupby.png', 'join_s.png', 'melb_data.csv', 'melb_data_fe.csv', 'movies_data.zip', 'ratings_movies.zip', 'students_performance.csv']
# ---
# Все пути:
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\data\citibike-tripdata.csv
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\data\countries.csv
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\data\countries.zip
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\data\data_ufo.csv
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\data\df_to_excel (2).xlsx
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\data\df_to_excel.xlsx
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\data\df_to_json.js
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\data\groupby.png
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\data\join_s.png
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\data\melb_data.csv
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\data\melb_data_fe.csv
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\data\movies_data.zip
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\data\ratings_movies.zip
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\data\students_performance.csv
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\data\movies_data
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\data\movies_data
# ---
# Папок нет
# ---
# Список файлов ['dates.csv', 'movies.csv', 'ratings1.csv', 'ratings2.csv']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\data\movies_data\dates.csv
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\data\movies_data\movies.csv
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\data\movies_data\ratings1.csv
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\data\movies_data\ratings2.csv
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\img
# ---
# Папок нет
# ---
# Список файлов ['axis.png', 'col_names.png', 'datetime.png', 'join.png', 'pdlogo.png', 'students.png', 'ufo_info.png', 'velocity.png']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\img\axis.png
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\img\col_names.png
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\img\datetime.png
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\img\join.png
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\img\pdlogo.png
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\img\students.png
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\img\ufo_info.png
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Конспект\img\velocity.png
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Литература
# ---
# Папок нет
# ---
# Список файлов ['Pandas_info.pdf', 'Абдрахманов М.И. - Pandas. Работа с данными - 2020.pdf', 'Конспект Pandas datetime.pdf', 'Конспект Pandas Join, Merge, Groupby, Sort_values.pdf', 'Конспект Pandas основы.pdf']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Литература\Pandas_info.pdf
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Литература\Абдрахманов М.И. - Pandas. Работа с данными - 2020.pdf
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Литература\Конспект Pandas datetime.pdf
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Литература\Конспект Pandas Join, Merge, Groupby, Sort_values.pdf
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Литература\Конспект Pandas основы.pdf
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа
# ---
# Список папок ['data', 'img']
# ---
# Список файлов ['Concat csv function.ipynb', 'Data analysis Melbourn realty .ipynb', 'Data analysis Students.ipynb', 'Data pre-processing Melbourn realty.ipynb', 'Data pre-processing UFO.ipynb', 'Data pre-processing VELO BIKE.ipynb', 'DF Groupby Pivot_table .ipynb', 'DF Merge, Groupby.ipynb', 'Tasks Concat Merge Join.ipynb', 'Tasks Sort Groupby Pivot.ipynb']
# ---
# Все пути:
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\Concat csv function.ipynb
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\Data analysis Melbourn realty .ipynb
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\Data analysis Students.ipynb
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\Data pre-processing Melbourn realty.ipynb
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\Data pre-processing UFO.ipynb
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\Data pre-processing VELO BIKE.ipynb
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\DF Groupby Pivot_table .ipynb
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\DF Merge, Groupby.ipynb
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\Tasks Concat Merge Join.ipynb
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\Tasks Sort Groupby Pivot.ipynb
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\data
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\img
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\data
# ---
# Список папок ['internet_shop', 'movies_data', 'users']
# ---
# Список файлов ['citibike-tripdata.csv', 'countries.csv', 'data_ufo.csv', 'df_to_excel.xlsx', 'df_to_json.js', 'melb_data.csv', 'melb_data_fe.csv', 'ratings_movies.csv', 'students_performance.csv']
# ---
# Все пути:
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\data\citibike-tripdata.csv
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\data\countries.csv
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\data\data_ufo.csv
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\data\df_to_excel.xlsx
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\data\df_to_json.js
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\data\melb_data.csv
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\data\melb_data_fe.csv
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\data\ratings_movies.csv
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\data\students_performance.csv
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\data\internet_shop
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\data\movies_data
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\data\users
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\data\internet_shop
# ---
# Папок нет
# ---
# Список файлов ['orders.csv', 'products.csv']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\data\internet_shop\orders.csv
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\data\internet_shop\products.csv
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\data\movies_data
# ---
# Папок нет
# ---
# Список файлов ['dates.csv', 'movies.csv', 'ratings1.csv', 'ratings2.csv']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\data\movies_data\dates.csv
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\data\movies_data\movies.csv
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\data\movies_data\ratings1.csv
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\data\movies_data\ratings2.csv
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\data\users
# ---
# Папок нет
# ---
# Список файлов ['u_1.csv', 'u_2.csv', 'u_3.csv', 'u_4.csv', 'u_5.csv', 'u_6.csv']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\data\users\u_1.csv
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\data\users\u_2.csv
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\data\users\u_3.csv
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\data\users\u_4.csv
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Python\4 - Pandas\Примеры анализа\data\users\u_5.csv
# ...
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Matplotlib\Теория\Лекции\mxmh_survey_results.csv
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Matplotlib\Теория\Лекции\Визуализации графики для ML.mp4
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Matplotlib\Теория\Лекции\Восприятие информации ч.1.mp4
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Matplotlib\Теория\Лекции\Восприятие информации ч.2.mp4
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Matplotlib\Теория\Лекции\Методы визуализации.mp4
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Matplotlib\Теория\Примеры
# ---
# Список папок ['data']
# ---
# Список файлов ['lms.mipt.ru_pluginfile.php_168669_mod_resource_content_1_Библиотека matplotlib.ipynb', 'lms.mipt.ru_pluginfile.php_168671_mod_resource_content_1_Примеры 3D-визуализации.ipynb']
# ---
# Все пути:
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Matplotlib\Теория\Примеры\lms.mipt.ru_pluginfile.php_168669_mod_resource_content_1_Библиотека matplotlib.ipynb
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Matplotlib\Теория\Примеры\lms.mipt.ru_pluginfile.php_168671_mod_resource_content_1_Примеры 3D-визуализации.ipynb
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Matplotlib\Теория\Примеры\data
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Matplotlib\Теория\Примеры\data
# ---
# Папок нет
# ---
# Список файлов ['cube.stl', 'tapok.csv', 'Tesla Model S.STL']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Matplotlib\Теория\Примеры\data\cube.stl
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Matplotlib\Теория\Примеры\data\tapok.csv
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Matplotlib\Теория\Примеры\data\Tesla Model S.STL
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных
# ---
# Список папок ['Практика', 'Семинар', 'Теория']
# ---
# Файлов нет
# ---
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Практика
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Семинар
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Теория
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Практика
# ---
# Список папок ['data']
# ---
# Список файлов ['Task Altair.ipynb']
# ---
# Все пути:
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Практика\Task Altair.ipynb
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Практика\data
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Практика\data
# ---
# Папок нет
# ---
# Список файлов ['altairlogo.png', 'output.png', 'superstore.csv', 'train.csv', 'visualization.png', 'visualization.svg']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Практика\data\altairlogo.png
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Практика\data\output.png
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Практика\data\superstore.csv
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Практика\data\train.csv
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Практика\data\visualization.png
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Практика\data\visualization.svg
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Семинар
# ---
# Список папок ['data']
# ---
# Список файлов ['Seminar Altair.ipynb']
# ---
# Все пути:
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Семинар\Seminar Altair.ipynb
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Семинар\data
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Семинар\data
# ---
# Папок нет
# ---
# Список файлов ['train.csv']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Семинар\data\train.csv
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Теория
# ---
# Список папок ['Конспект', 'Лекции']
# ---
# Файлов нет
# ---
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Теория\Конспект
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Теория\Лекции
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Теория\Конспект
# ---
# Список папок ['data']
# ---
# Список файлов ['Altair.ipynb', 'altair_introduction.ipynb']
# ---
# Все пути:
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Теория\Конспект\Altair.ipynb
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Теория\Конспект\altair_introduction.ipynb
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Теория\Конспект\data
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Теория\Конспект\data
# ---
# Папок нет
# ---
# Список файлов ['altairlogo.png', 'superstore.csv', 'train.csv']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Теория\Конспект\data\altairlogo.png
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Теория\Конспект\data\superstore.csv
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Теория\Конспект\data\train.csv
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Теория\Лекции
# ---
# Папок нет
# ---
# Список файлов ['Altair.mp4', 'DataLens.mp4', 'lms.mipt.ru_pluginfile.php_169129_mod_resource_content_1_altair-demo.ipynb', 'lms.mipt.ru_pluginfile.php_169131_mod_resource_content_1_seaborn-demo.ipynb', 'Seaborn.mp4', 'Конспект Прикладные инструменты визуализации .pdf']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Теория\Лекции\Altair.mp4
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Теория\Лекции\DataLens.mp4
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Теория\Лекции\lms.mipt.ru_pluginfile.php_169129_mod_resource_content_1_altair-demo.ipynb
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Теория\Лекции\lms.mipt.ru_pluginfile.php_169131_mod_resource_content_1_seaborn-demo.ipynb
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Теория\Лекции\Seaborn.mp4
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инструменты визуализации данных\Теория\Лекции\Конспект Прикладные инструменты визуализации .pdf
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инфопанели и презентации
# ---
# Список папок ['Практика', 'Семинар', 'Теория']
# ---
# Файлов нет
# ---
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инфопанели и презентации\Практика
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инфопанели и презентации\Семинар
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инфопанели и презентации\Теория
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инфопанели и презентации\Практика
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инфопанели и презентации\Семинар
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инфопанели и презентации\Теория
# ---
# Список папок ['Видео', 'Конспект']
# ---
# Файлов нет
# ---
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инфопанели и презентации\Теория\Видео
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инфопанели и презентации\Теория\Конспект
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инфопанели и презентации\Теория\Видео
# ---
# Папок нет
# ---
# Список файлов ['3.1 Интерактивные средства и связанные представления.mp4', '3.2 Презентации на основе диаграмм. Общие практики.mp4', '3.3 Подготовка инфопанелей и презентаций с помощью Yandex DataLens.mp4', '3.4 Подготовка инфопанелей и презентаций с помощью библиотеки Altair.mp4']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инфопанели и презентации\Теория\Видео\3.1 Интерактивные средства и связанные представления.mp4
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инфопанели и презентации\Теория\Видео\3.2 Презентации на основе диаграмм. Общие практики.mp4
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инфопанели и презентации\Теория\Видео\3.3 Подготовка инфопанелей и презентаций с помощью Yandex DataLens.mp4
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инфопанели и презентации\Теория\Видео\3.4 Подготовка инфопанелей и презентаций с помощью библиотеки Altair.mp4
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инфопанели и презентации\Теория\Конспект
# ---
# Список папок ['data']
# ---
# Список файлов ['03 Диаграммы в контексте_ инфопанели и презентации.pdf', 'lms.mipt.ru_pluginfile.php_169134_mod_resource_content_1_altair-dashboard.ipynb', 'lms.mipt.ru_pluginfile.php_169135_mod_resource_content_1_altair-dashboard-v5.ipynb']
# ---
# Все пути:
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инфопанели и презентации\Теория\Конспект\03 Диаграммы в контексте_ инфопанели и презентации.pdf
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инфопанели и презентации\Теория\Конспект\lms.mipt.ru_pluginfile.php_169134_mod_resource_content_1_altair-dashboard.ipynb
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инфопанели и презентации\Теория\Конспект\lms.mipt.ru_pluginfile.php_169135_mod_resource_content_1_altair-dashboard-v5.ipynb
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инфопанели и презентации\Теория\Конспект\data
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инфопанели и презентации\Теория\Конспект\data
# ---
# Папок нет
# ---
# Список файлов ['superstore.xlsx']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Инфопанели и презентации\Теория\Конспект\data\superstore.xlsx
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Проектное задание
# ---
# Список папок ['data']
# ---
# Список файлов ['project (2).ipynb', 'project (3).ipynb', 'project.ipynb', 'Семинар_2_2_ipynb_.ipynb']
# ---
# Все пути:
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Проектное задание\project (2).ipynb
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Проектное задание\project (3).ipynb
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Проектное задание\project.ipynb
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Проектное задание\Семинар_2_2_ipynb_.ipynb
# Папка  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Проектное задание\data
# ===
# Текущая директория c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Проектное задание\data
# ---
# Папок нет
# ---
# Список файлов ['vgsales.csv.zip']
# ---
# Файл  c:\Users\nazar\YandexDisk\MIPT.Data Science\Продвинутые методы машинного обучения\2. Визуализация данных\Проектное задание\data\vgsales.csv.zip
# ===

# %% [markdown]
# ____
# ## <a id= 'f'>Чтение и запись файлов</a>

# %%
with open('file.txt','w') as file:
    file.write('1\n')
    file.write('2\n')
    file.writelines(['3\n', '4\n'])

# %%
with open('file.txt', 'r') as f:

    txt_lines = f.readline()
    print( txt_lines)

    for line in f:
        print(line)
# Out:
# Some text
#
# Another text
#
# from list
#
# another from list

# %% [markdown]
# ___
# ## <a id= 'try'>try - except</a>
# - `except` : Код исполнится после возникновения исключения
# - `else` : Код исполнится если  исключение не возникло
# - `finally` : Код исполнится в любом случае

# %%
try:
    a = int(input('Число для приведения в int: '))
except ValueError:
    print('Код после исключения!')
else:
    print('Код, если исключения не было')
finally:
    print('Всегда отрабатывает')
# Out:
# Код после исключения!
# Всегда отрабатывает

# %% [markdown]
# ___
# # Кастомный класс исключения

# %%
class NonPositiveDigitException(ValueError):
    pass

class Square:
    def __init__(self, a):
        if a <= 0:
            raise NonPositiveDigitException('Неправильно указана сторона квадрата')

square = Square(-1)
# Out:
# ---------------------------------------------------------------------------
# NonPositiveDigitException                 Traceback (most recent call last)
# d:\Learning\Yandex Disk Sync\YandexDisk\MIPT.Data Science\Python\9 - ООП.ipynb\OOP.ipynb Ячейка 21 line 9
#       <a href='vscode-notebook-cell:/d%3A/Learning/Yandex%20Disk%20Sync/YandexDisk/MIPT.Data%20Science/Python/9%20-%20%D0%9E%D0%9E%D0%9F.ipynb/OOP.ipynb#X26sZmlsZQ%3D%3D?line=5'>6</a>         if a <= 0:
#       <a href='vscode-notebook-cell:/d%3A/Learning/Yandex%20Disk%20Sync/YandexDisk/MIPT.Data%20Science/Python/9%20-%20%D0%9E%D0%9E%D0%9F.ipynb/OOP.ipynb#X26sZmlsZQ%3D%3D?line=6'>7</a>             raise NonPositiveDigitException('Неправильно указана сторона квадрата')
# ----> <a href='vscode-notebook-cell:/d%3A/Learning/Yandex%20Disk%20Sync/YandexDisk/MIPT.Data%20Science/Python/9%20-%20%D0%9E%D0%9E%D0%9F.ipynb/OOP.ipynb#X26sZmlsZQ%3D%3D?line=8'>9</a> square = Square(-1)
#
# d:\Learning\Yandex Disk Sync\YandexDisk\MIPT.Data Science\Python\9 - ООП.ipynb\OOP.ipynb Ячейка 21 line 7
#       <a href='vscode-notebook-cell:/d%3A/Learning/Yandex%20Disk%20Sync/YandexDisk/MIPT.Data%20Science/Python/9%20-%20%D0%9E%D0%9E%D0%9F.ipynb/OOP.ipynb#X26sZmlsZQ%3D%3D?line=4'>5</a> def __init__(self, a):
#       <a href='vscode-notebook-cell:/d%3A/Learning/Yandex%20Disk%20Sync/YandexDisk/MIPT.Data%20Science/Python/9%20-%20%D0%9E%D0%9E%D0%9F.ipynb/OOP.ipynb#X26sZmlsZQ%3D%3D?line=5'>6</a>     if a <= 0:
# ----> <a href='vscode-notebook-cell:/d%3A/Learning/Yandex%20Disk%20Sync/YandexDisk/MIPT.Data%20Science/Python/9%20-%20%D0%9E%D0%9E%D0%9F.ipynb/OOP.ipynb#X26sZmlsZQ%3D%3D?line=6'>7</a>         raise NonPositiveDigitException('Неправильно указана сторона квадрата')
#
# NonPositiveDigitException: Неправильно указана сторона квадрата
